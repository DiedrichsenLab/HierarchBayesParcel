# %% [markdown]
# # Generation of brain activity data with `PottsModel`
# The class `PottsModel` in `simulate.py` implements a generative model of brain activity data. It generates a group of subjects with slightly different arrangements of functional regions - and then makes some functional data. This data set can serve as a sandbox for brain parcellation and brain connectivity estimation algorithms. For mathematical details, see the `README.md` document.

# %% [markdown]
# ## Generate the model and the group-parcellation

# %%
# Import the Pottsmodel Class 
from simulate import PottsModel
import numpy as np
import matplotlib.pyplot as plt 
import pandas
import plotly.express as px
import plotly.graph_objects as go
# Generate a Pottsmodel on a rectangular 30x30 Grid
M = PottsModel(5,30,30)
# Define the parcellation + Prior Probability  
M.define_mu(200)
# Show the clustering 
plt.figure(figsize=(2,2))
cluster = np.argmax(M.mu,axis=0)
M.plot_maps(cluster)

# %%
# Show the prior probabilities for the different parcels 
plt.figure(figsize=(10,2))
M.plot_maps(M.mu,cmap='jet',vmax=1,grid=[1,5])

# %% [markdown]
# ## Gibbs sampling from Prior
# Hint: Try the influence of changing the temperature parameter

# %%
# Demostrate a single Gibbs sample, starting from a random start (drawn indpendentlu from mu) 
M.theta_w = 5 # inverse temperature parameter
Us = M.sample_gibbs(prior=True,iter=19)
plt.figure(figsize=(22,4))
M.plot_maps(Us,cmap='tab20',grid=[2,10])

# %% [markdown]
# ## Sample individual Subjects from the Prior probability distribution
# Now we can get a number of Subjects from the prior distribution

# %%
num_subj = 10 
U = np.zeros((num_subj,M.P))
for i in range(num_subj):
    Us = M.sample_gibbs(prior=True,iter=10)
    U[i,:]=Us[-1,:]
plt.figure(figsize=(10,4))
M.plot_maps(U,cmap='tab20',grid=[2,5])

# %%
## Generate a data set for a specific experiment
# We can now generate a data set for a specific experiment. 
U = M.generate_subjects(num_subj = 4)
[Y,param] = M.generate_emission(U)

# %%
Y.shape
# Out:
# (4, 30, 900)

# %%
fig = px.scatter_3d(x=Y[0,0,:],y=Y[0,1,:],z=Y[0,2,:],opacity=0.3,template='plotly_white')
fig.show()
# Out:
# <div>                            <div id="5cefbe14-a61b-43e6-af68-278a81bbff50" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5cefbe14-a61b-43e6-af68-278a81bbff50")) {                    Plotly.newPlot(                        "5cefbe14-a61b-43e6-af68-278a81bbff50",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>z=%{z}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","opacity":0.3,"symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"type":"scatter3d","x":[2.895072700608029,2.9088817419206605,5.001416840955954,2.1444092725134443,3.2228395525410924,5.259900256439833,2.926246793119055,3.4037691032705664,-1.9852081841914777,-0.9910309054741834,0.7011672591106933,-1.1048940260706746,0.10187530254168004,-1.2813742477327552,1.1648496076520682,1.389323405345571,0.9774615211304749,0.2685698612332472,-0.9529880750593598,1.3061428519304519,-0.652866346679162,-0.3004876822775452,-1.4901911278832993,-1.7139019025755138,-3.7878646753833753,-3.816950724004422,-0.3541329803988882,-1.8228473668093272,-2.060827470690537,-1.842565710897611,3.7615207283971444,2.6603041536514,2.527629051096188,-0.16502461041521288,4.8298779670984056,3.8174257111691863,3.330129625412633,4.662226816421614,-1.822278144809801,-2.384720322980515,-0.8286159022929731,-0.022674569063798167,-1.5533251138132878,-1.7318436554849905,-0.29898619712046426,1.8758973805067347,-0.6064862101015519,-2.0382360621948745,-3.407184713224627,-1.8886717275773164,0.8680737086792741,-3.057706626626618,-1.2599526840477635,-4.287011745408208,-1.9904675125418305,-2.850315240152139,-2.8424496109226816,-1.593538382178979,-2.199125787177566,1.9437992407358062,1.4884999853554781,5.100915765955558,4.335668696783818,1.704843343742504,4.796485303012853,4.323332285678263,3.2470156389038456,2.5014873491368625,-3.5029050403473807,0.8149450545194004,-2.8685377690730753,-0.7360123468013919,-1.763349591671074,0.954284467335082,-0.8000098020887529,-1.3046703636615664,0.5395104485473521,-1.195148678598704,0.5595031909957872,0.8533551117220455,-0.6541593739072951,1.6213558022418886,-2.3138453504648906,-1.5711676873564397,-2.1395848323175377,-5.324286976090472,0.6504519731638932,-2.5892174428224926,-1.3191062285203732,-5.8107197869725375,2.656905090449136,2.7982194411949117,-0.13053300150521102,-0.014154339956696571,2.560577723300845,-1.0410730901643457,2.2332481917683453,7.867749917526008,-1.120212990288886,-0.11925905230445899,-0.8372074359688756,2.5840909082264893,-2.0707340732153066,-0.7484903912331874,-2.701126892021552,-1.0583764485284313,-0.9493068912795138,-1.0886121387573264,-0.18281892344081974,1.3225427015688678,0.2011715679516149,-3.926220960219774,-0.9810135798297952,-0.9645433397305233,-2.498465320718348,-3.587714106519155,-1.1664256124638195,-0.6628253720944368,-1.1845592840155268,0.7761600483710862,3.538907451739184,2.6410862508572777,3.056161578287881,0.08898351849991454,3.1097953554000197,4.231188294770664,4.753142898329835,2.374207254815112,-2.490800185915255,-1.3647296586920707,1.3719324338133754,-0.4194966867008976,-3.769666067209711,-0.9527684661937695,-0.8915994874851527,1.2151621706908518,-0.2097664252402528,-0.5766488983626105,-0.12067174798191393,0.2627372887600109,-1.1146985914029408,-1.970754285380326,-7.551374734214444,-1.5102628612415239,1.873509343690984,-0.32473990039532663,0.26042475412702953,-1.7245314664630127,-3.1727773794494802,0.20629317194710595,5.968991702810223,6.228523176050039,3.0481919282705943,-0.3114126255502063,0.15072645766265264,1.3897439146776553,4.1719985279761005,-0.2868661723307971,0.6996792636748463,0.8596654807431511,-0.11312465507787392,-0.023812055643232924,-1.7682619576658856,-1.2038616664370938,-1.2458574748735805,-1.3119745107804315,-0.8213433234062127,-1.78428 ...

# %%
import plotly.graph_objects as go
from ipywidgets import widgets
V = param['V']*2 

fig = go.Figure()
s = 0
t = [0,1,2]
fig.add_scatter3d(x=Y[s,t[0],:],y=Y[s,t[1],:],z=Y[s,t[2],:],opacity=0.3,mode = 'markers',marker=dict(size=3,color='blue'))
for k in range(M.K):
    fig.add_scatter3d(x=[0,V[0,k]],y=[0,V[1,k]],z=[0,V[2,k]],mode = 'lines',line=dict(width=6,color='red'))
fig.show()
# Out:
# <div>                            <div id="db27a565-2f3d-447b-ae23-a711214ad73f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db27a565-2f3d-447b-ae23-a711214ad73f")) {                    Plotly.newPlot(                        "db27a565-2f3d-447b-ae23-a711214ad73f",                        [{"marker":{"color":"blue","size":3},"mode":"markers","opacity":0.3,"type":"scatter3d","x":[2.895072700608029,2.9088817419206605,5.001416840955954,2.1444092725134443,3.2228395525410924,5.259900256439833,2.926246793119055,3.4037691032705664,-1.9852081841914777,-0.9910309054741834,0.7011672591106933,-1.1048940260706746,0.10187530254168004,-1.2813742477327552,1.1648496076520682,1.389323405345571,0.9774615211304749,0.2685698612332472,-0.9529880750593598,1.3061428519304519,-0.652866346679162,-0.3004876822775452,-1.4901911278832993,-1.7139019025755138,-3.7878646753833753,-3.816950724004422,-0.3541329803988882,-1.8228473668093272,-2.060827470690537,-1.842565710897611,3.7615207283971444,2.6603041536514,2.527629051096188,-0.16502461041521288,4.8298779670984056,3.8174257111691863,3.330129625412633,4.662226816421614,-1.822278144809801,-2.384720322980515,-0.8286159022929731,-0.022674569063798167,-1.5533251138132878,-1.7318436554849905,-0.29898619712046426,1.8758973805067347,-0.6064862101015519,-2.0382360621948745,-3.407184713224627,-1.8886717275773164,0.8680737086792741,-3.057706626626618,-1.2599526840477635,-4.287011745408208,-1.9904675125418305,-2.850315240152139,-2.8424496109226816,-1.593538382178979,-2.199125787177566,1.9437992407358062,1.4884999853554781,5.100915765955558,4.335668696783818,1.704843343742504,4.796485303012853,4.323332285678263,3.2470156389038456,2.5014873491368625,-3.5029050403473807,0.8149450545194004,-2.8685377690730753,-0.7360123468013919,-1.763349591671074,0.954284467335082,-0.8000098020887529,-1.3046703636615664,0.5395104485473521,-1.195148678598704,0.5595031909957872,0.8533551117220455,-0.6541593739072951,1.6213558022418886,-2.3138453504648906,-1.5711676873564397,-2.1395848323175377,-5.324286976090472,0.6504519731638932,-2.5892174428224926,-1.3191062285203732,-5.8107197869725375,2.656905090449136,2.7982194411949117,-0.13053300150521102,-0.014154339956696571,2.560577723300845,-1.0410730901643457,2.2332481917683453,7.867749917526008,-1.120212990288886,-0.11925905230445899,-0.8372074359688756,2.5840909082264893,-2.0707340732153066,-0.7484903912331874,-2.701126892021552,-1.0583764485284313,-0.9493068912795138,-1.0886121387573264,-0.18281892344081974,1.3225427015688678,0.2011715679516149,-3.926220960219774,-0.9810135798297952,-0.9645433397305233,-2.498465320718348,-3.587714106519155,-1.1664256124638195,-0.6628253720944368,-1.1845592840155268,0.7761600483710862,3.538907451739184,2.6410862508572777,3.056161578287881,0.08898351849991454,3.1097953554000197,4.231188294770664,4.753142898329835,2.374207254815112,-2.490800185915255,-1.3647296586920707,1.3719324338133754,-0.4194966867008976,-3.769666067209711,-0.9527684661937695,-0.8915994874851527,1.2151621706908518,-0.2097664252402528,-0.5766488983626105,-0.12067174798191393,0.2627372887600109,-1.1146985914029408,-1.970754285380326,-7.551374734214444,-1.5102628612415239,1.873509343690984,-0.32473990039532663,0.26042475412702953,-1.7245314664630127,-3.1727773794494802,0.20629317194710595,5.968991702810223,6.228523176050039,3.0481919282705943,-0.3114126255502063,0.15072645766265264,1.3897439146776553,4.1719985279761005,-0.2868661723307971,0.6996792636748463,0.8596654807431511,-0.11312465507787392,-0.023812055643232924,-1.7682619576658856,-1.2038616664370938,-1.2458574748735805,-1.3119745107804315,-0.8213433234062127,-1.784283312841629,-1.2186016955133678,-2.4036876048053255,-0.7963313022932341,-2.5349568753019014,-5.23775783723519,-4.354984364313575,-0.476 ...

# %%
V= param['V']
V
# Out:
# array([[-1.52829207,  1.0914108 ,  0.19264482,  0.26326882,  0.18152002],
#        [ 0.1564155 ,  0.37535795,  0.80984256,  0.94993691, -0.92145667],
#        [ 2.07623011,  1.98749316,  0.88587492,  1.08191302,  0.80633426],
#        [ 1.31296122,  1.78972901, -0.69922636,  0.64676418, -1.89897039],
#        [-0.34135925, -1.45549187,  0.63896875, -0.31813324, -0.73478289],
#        [ 0.15507164, -0.41575857,  0.86657075,  1.21534278, -0.04025651],
#        [ 0.33694843,  0.62708668,  0.2310223 , -1.71384499, -0.65186723],
#        [ 0.91993218, -0.16524931, -1.35203808, -0.89509389,  1.44231749],
#        [-1.01988018, -0.27330578,  1.79371847, -1.17880409, -0.09604428],
#        [ 0.69124062, -0.05248877, -0.29115781,  0.79398755,  0.24240675],
#        [ 0.12842242, -1.50816182, -0.16501468, -1.00866604,  0.7952527 ],
#        [-1.98552842,  1.31959253,  1.30403172, -1.58935693, -2.33507617],
#        [ 0.53868848,  0.40913322, -0.82719281,  0.89626653, -0.66633331],
#        [-0.94531443,  0.41480737,  0.61040767, -0.27037054, -0.34736328],
#        [-0.12709857, -1.52732632, -0.30196639,  0.60843791, -0.17403174],
#        [-0.07672652, -1.09748575, -0.71117467,  0.46594786,  0.2112054 ],
#        [ 0.33762484, -0.98092019, -0.06730003, -1.10920417,  0.86782606],
#        [ 0.89412225,  0.64407371, -0.70678366, -1.13017107, -0.74434301],
#        [-0.39494363,  0.36305263, -1.01154431, -1.08478057,  0.72452835],
#        [ 1.1906248 ,  1.69228539,  0.32916858,  0.27109672, -0.45801625],
#        [ 0.29775293, -1.01886526,  0.41938222,  0.57058537,  1.42249806],
#        [-0.06706136, -1.18825473, -1.20856635,  0.11055032,  1.69301423],
#        [ 1.00680941, -0.62173309,  2.31278529,  0.80712643, -0.96251029],
#        [-0.34392624,  0.91564975, -0.74197133, -2.06895629,  0.41368464],
#        [-0.11128877, -0.4796017 , -1.52421184,  0.05354376, -0.16470555],
#        [-0.81442822, -0.28975245, -1.97057365,  2.02087249,  0.64159272],
#        [-1.24223189, -0.72241699, -0.43390436, -0.21685531,  1.49481635],
#        [ 1.88577429,  1.18657681,  1.33174089,  1.34279009, -1.84284622],
#        [-1.32185765, -0.40554381,  0.82446147,  0.32351385,  0.94897078],
#        [-1.60868191, -0.61389261, -0.53799407,  0.16229256,  0.15263597]])
